# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = cv2.imread('wrong/path/doent/kjabdsfljas.jpg')

# %%
type(img)
# Out:
# NoneType

# %%
img = cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB --> RGB RED GREEN BLUE
# OPENCV ---> BLUE GREEN RED

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
im_gray = cv2.imread('DATA/00-puppy.jpg', cv2.IMREAD_GRAYSCALE)

# %%
im_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(cv2.cvtColor(im_gray, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fix_img, (1000, 400))

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (400, 1000, 3)

# %%
w_ratio = 0.8
h_ratio = 0.2

# %%
# resize by ratio
new_img = cv2.resize(fix_img, (0,0), fix_img, w_ratio, h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (260, 1560, 3)

# %%
# flip => 0: horizontal 1: vertical -1:both
new_img = cv2.flip(fix_img, -1)
plt.imshow(new_img)

# %%
type(new_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new_img.jpg', fix_img)
# Out:
# True

# %%
# show the image better (how to see it in the Jupyter notebook)
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
